# %% [markdown]
# ### Import

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# %matplotlib inline

from tqdm import tqdm
import joblib

# %% [markdown]
# ### Load DataFrame

# %%
best_game_df = joblib.load('../preprocessing/game_pkl/best_games_150.pkl')
best_game_df
# Out:
#              platform                                        title  \
# 0                  DS               Ghost Trick: Phantom Detective
# 1                 PSP  Z.H.P. Unlosing Ranger vs Darkdeath Evilman
# 2                  DS                                Metal Torrent
# 3            Xbox One                                 Superliminal
# 4              Switch                                 Superliminal
# ..                ...                                          ...
# 145     PlayStation 2                          Burnout 3: Takedown
# 146          GameCube                                     Pikmin 2
# 147                PC       Star Wars: Knights of the Old Republic
# 148     PlayStation 2              Ratchet & Clank: Going Commando
# 149  Game Boy Advance                Final Fantasy Tactics Advance
#
#                publisher                                             static  \
# 0                 Capcom  {'user': {'positive': 1552, 'mixed': 12, 'nega...
# ...

# %% [markdown]
# 하위 dict의 자료형이 궁금하네요

# %%
type(best_game_df.at[0, 'detail'])
# Out:
# dict

# %%
worst_game_df = pd.read_pickle('../preprocessing/game_pkl/game_df_w50.pkl')
worst_game_df
# Out:
#          platform                                              title  \
# 0   PlayStation 4                                      Madden NFL 21
# 1              PC                                    Diablo Immortal
# 2          Switch  Grand Theft Auto: The Trilogy - The Definitive...
# 3              PC  Tom Clancy's The Division 2: Warlords of New York
# 4   PlayStation 4                                           NBA 2K21
# 5   PlayStation 5  Grand Theft Auto: The Trilogy - The Definitive...
# 6   PlayStation 4  Tom Clancy's The Division 2: Warlords of New York
# 7              PC           The Sims 4: Star Wars - Journey to Batuu
# 8              DS          Call of Duty: Modern Warfare 3 - Defiance
# 9        Xbox 360                           Fast & Furious: Showdown
# 10       Xbox One                                           WWE 2K20
# 11  PlayStation 5                                     eFootball 2022
# 12       Xbox One                                      Madden NFL 21
# ...

# %% [markdown]
# ### 게임 평점 시각화

# %%
user_mean_list = []
critic_mean_list = []

for row in tqdm(best_game_df.itertuples(), 'list building...', best_game_df.shape[0]):
    user_mean_list.append(row[4]['user']['mean'])
    critic_mean_list.append(row[4]['critic']['mean'])

user_mean_list
# Out:
# list building...: 100%|███████████████████████████████████████████████████████████| 150/150 [00:00<00:00, 75211.67it/s]
# [9.7,
#  9.7,
#  9.7,
#  9.6,
#  9.6,
#  9.6,
#  9.6,
#  9.6,
#  9.6,
#  9.5,
#  9.4,
#  9.4,
#  9.4,
#  9.4,
#  9.3,
#  9.3,
#  9.3,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.2,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.1,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
# ...

# %%
# 1. 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (6, 6)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(150)
y1 = np.array(user_mean_list)
y2 = np.array(critic_mean_list)

# 3. 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y1, color='#33FF88', markersize=7, linewidth=3, alpha=0.7, label='User')
ax1.set_ylim(8.9, 9.8)
ax1.set_ylabel('user score')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.plot(x, y2, color='#FF6666', markersize=7, linewidth=3, alpha=0.7, label='Critic')
ax2.set_ylim(40, 100)
ax2.set_ylabel('critic score')
ax2.tick_params(axis='y', direction='in')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### 게임 플랫폼(기기) 분포 시각화

# %%
pc_or_not_list = [0, 0]

for row in tqdm(best_game_df.itertuples(), 'list building...', best_game_df.shape[0]):
    pc_or_not_list[0 if row[1] == 'PC' else 1] += 1

pc_or_not_list
# Out:
# list building...: 100%|███████████████████████████████████████████████████████████| 150/150 [00:00<00:00, 75121.86it/s]
# [46, 104]

# %%
# 1. 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (6, 6)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.array(['PC', 'Console'])
y = np.array(pc_or_not_list)

# 3. 그래프 그리기
plt.barh(x, y)
plt.show()

# %%
platform_value_count = best_game_df['platform'].value_counts().copy()

# %%
# 1. 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (6, 6)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.array(platform_value_count.index.copy())
y = platform_value_count.values

# 3. 그래프 그리기
plt.barh(x, y)
# plt.xticks(rotation=55)
plt.show()

# %% [markdown]
# ### 리뷰 갯수

# %%
import glob

# %%
glob.glob('c:/Windows/Fonts/*')
# Out:
# ['c:/Windows/Fonts\\8514fix.fon',
#  'c:/Windows/Fonts\\8514fixe.fon',
#  'c:/Windows/Fonts\\8514fixg.fon',
#  'c:/Windows/Fonts\\8514fixr.fon',
#  'c:/Windows/Fonts\\8514fixt.fon',
#  'c:/Windows/Fonts\\8514oem.fon',
#  'c:/Windows/Fonts\\8514oeme.fon',
#  'c:/Windows/Fonts\\8514oemg.fon',
#  'c:/Windows/Fonts\\8514oemr.fon',
#  'c:/Windows/Fonts\\8514oemt.fon',
#  'c:/Windows/Fonts\\8514sys.fon',
#  'c:/Windows/Fonts\\8514syse.fon',
#  'c:/Windows/Fonts\\8514sysg.fon',
#  'c:/Windows/Fonts\\8514sysr.fon',
#  'c:/Windows/Fonts\\8514syst.fon',
#  'c:/Windows/Fonts\\85775.fon',
#  'c:/Windows/Fonts\\85855.fon',
#  'c:/Windows/Fonts\\85f1255.fon',
#  'c:/Windows/Fonts\\85f1256.fon',
#  'c:/Windows/Fonts\\85f1257.fon',
#  'c:/Windows/Fonts\\85f874.fon',
#  'c:/Windows/Fonts\\85s1255.fon',
#  'c:/Windows/Fonts\\85s1256.fon',
#  'c:/Windows/Fonts\\85s1257.fon',
#  'c:/Windows/Fonts\\85s874.fon',
#  'c:/Windows/Fonts\\app775.fon',
#  'c:/Windows/Fonts\\app850.fon',
# ...

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:\\Windows\\Fonts\\HANBatang.ttf").get_name()
# font_name
rc('font', family=font_name)

# %%
# 1. 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 12)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = best_game_df.index
y = np.array(best_game_df['review number'])

# 3. 그래프 그리기
plt.barh(x, y)
# plt.title('리뷰 갯수')
plt.show()
